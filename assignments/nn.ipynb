# %% [markdown]
# # Mandatory Assignment 1
#
# #### Part I: Multi-layer Perceptron
#
# ***
#
# Please see the description of the assignment in the README file (section 1) <br>
# **Guide notebook**: [material/nns_pytorch.ipynb](material/nns_pytorch.ipynb)
#
# Table of contents:
# 1. Activate GPU
# 2. Load data
# 3. Inspect data
# 4. Artificial neural network (**Where you will implement the ANN**)
# 5. Training hyperparameters (**Where you will add training parameters**)
# 6. Training
# 7. Plot loss and accuracy
# 8. Evaluate

# %%
# auxilary imports
import random
import matplotlib.pyplot as plt
import os
from pathlib import Path

# pytorch
import torch
import torch.nn as nn
from torchvision import transforms
import torch.nn.functional as F  # noqa

# %% [markdown]
# First, a bit of a hack in case your IDE wants to run the notebook from /`assignment/` and not the project root folder `/ma1`. We need the working directory to be `/ma1` for local imports to work.

# %%
# Ensure the working directory is set to the "ma1" folder.
while Path.cwd().name != "ma1" and "ma1" in str(Path.cwd()):
    os.chdir("..")  # Move up one directory
print(f"Working directory set to: {Path.cwd()}")
# Out:
# Working directory set to: c:\Users\charl\Documents\CBS\Code Projects_Python\AIML25\mas\ma1

# %% [markdown]
# ##### Import local files
#
# To declutter the notebooks, your are given a module (`/src`) of useful functions. Please study each one as they contain important code (particularly `src.training` and `src.evaluation`).

# %%
# local files
from src.utils import get_device
from src.data import load_torch_data, to_dataloader, train_val_split
from src.training import fit
from src.evaluation import evaluate
from src.visualize import plot_training_history

# %% [markdown]
# ### 1. Activate GPU
# If available. Note that this is not necessary, but it will speed up your training.

# %%
# Device will determine whether to run the training on GPU or CPU.
DEVICE = get_device()
# Out:
# Running pytorch version (2.5.1) with backend = cpu

# %% [markdown]
# ### 2. Load data

# %%
# load the training/validation data
train_val = load_torch_data(
    dataset="MNIST",
    root = 'data',                     # The root directory where the dataset will be stored
    download = True,                   # If the dataset is not found at root, it will be downloaded
    train = True,                      # The train dataset (as opposed to the test dataset)
    transform = transforms.ToTensor()  # transformations to be applied to the dataset (only cast to tensor)
)

# load the testing data
test = load_torch_data(
    dataset = "MNIST",
    root = 'data',
    download = True,
    train = False,
    transform = transforms.ToTensor()
)

f"{len(train_val)=}, {len(test)=}"
# Out:
# 'len(train_val)=60000, len(test)=10000'

# %%
# split training data in training and validation (just like train_test_split in sklearn)
train, val = train_val_split(train_val, val_ratio=0.2, seed=42)

f"{len(val)=}, {len(train)=}"
# Out:
# 'len(val)=12000, len(train)=48000'

# %%
# create dataloders for easy batch loading during training
train_loader = to_dataloader(train, batch_size = 64, shuffle = True)
val_loader = to_dataloader(val, batch_size = 64, shuffle = False)
test_loader = to_dataloader(test, batch_size = 64, shuffle = False)

# %% [markdown]
# ### 3. Inspect data

# %%
# Pick a random example from the training set
selection = random.randrange(len(train)-1)
image, label = train[selection]

# Plot the image
print(f"Default image shape: {image.shape}")
image = image.view([28,28])

print(f"Reshaped image shape: {image.shape}")
plt.imshow(image, cmap="gray")

print(f"Total pixels: {image.shape[0] * image.shape[1]}")

# Print the label
print(f"The label for this image: {label}")
# Out:
# Default image shape: torch.Size([1, 28, 28])
# Reshaped image shape: torch.Size([28, 28])
# Total pixels: 784
# The label for this image: 3

# %% [markdown]
# ***
#
# ### 4. Artificial neural network

# %%
class MLP(nn.Module):

  def __init__(self):
    super().__init__()

    #define layers
    self.fc1 = nn.Linear(784, 300)
    self.fc2 = nn.Linear(300, 10)    
    self.relu = nn.ReLU()
   
  
  def forward(self, x : torch.Tensor):

    #define forward pass
    x = self.relu(self.fc1(x))
    #x = F.relu(x)
    x = self.fc2(x)

    return x

# %% [markdown]
# ### 5. Training hyperparameters

# %%
LR = 0.1  # define the learning rate
NUM_EPOCHS = 10 #define the number of epochs (i.e. passes over the dataset)
criterion = nn.CrossEntropyLoss()  # The loss function

# %% [markdown]
# Instantiate the model and optimizer

# %%
model = MLP().to(DEVICE)   # Create an instance of the MLP model and move it to device (GPU or CPU)
optimizer = torch.optim.SGD(model.parameters(), lr=LR) # The optimizer (here, SGD - you can also try ADAM)

# %%
model
# Out:
# MLP(
#   (fc1): Linear(in_features=784, out_features=300, bias=True)
#   (fc2): Linear(in_features=300, out_features=10, bias=True)
#   (relu): ReLU()
# )

# %% [markdown]
# ### 6. Training

# %%
model, history = fit(
    model,
    train_loader = train_loader,
    val_loader = val_loader,
    device = DEVICE,
    optimizer = optimizer,
    criterion = criterion,
    num_epochs = NUM_EPOCHS
)
# Out:
# Epoch [1/10]: Train Loss: 0.4714 | Train Accuracy: 87.54% | Val Loss: 0.3113 | Val Accuracy: 90.71%
# Epoch [2/10]: Train Loss: 0.2365 | Train Accuracy: 93.26% | Val Loss: 0.2196 | Val Accuracy: 93.78%
# Epoch [3/10]: Train Loss: 0.1801 | Train Accuracy: 94.83% | Val Loss: 0.1865 | Val Accuracy: 94.82%
# Epoch [4/10]: Train Loss: 0.1457 | Train Accuracy: 95.85% | Val Loss: 0.1582 | Val Accuracy: 95.44%
# Epoch [5/10]: Train Loss: 0.1214 | Train Accuracy: 96.58% | Val Loss: 0.1382 | Val Accuracy: 96.01%
# Epoch [6/10]: Train Loss: 0.1035 | Train Accuracy: 97.14% | Val Loss: 0.1243 | Val Accuracy: 96.29%
# Epoch [7/10]: Train Loss: 0.0899 | Train Accuracy: 97.52% | Val Loss: 0.1146 | Val Accuracy: 96.55%
# Epoch [8/10]: Train Loss: 0.0792 | Train Accuracy: 97.80% | Val Loss: 0.1070 | Val Accuracy: 96.92%
# Epoch [9/10]: Train Loss: 0.0706 | Train Accuracy: 98.03% | Val Loss: 0.1055 | Val Accuracy: 96.78%
# Epoch [10/10]: Train Loss: 0.0629 | Train Accuracy: 98.32% | Val Loss: 0.1000 | Val Accuracy: 97.12%

# %% [markdown]
# ### 7. Plot loss and accuracy

# %%
plot_training_history(history)

# %% [markdown]
# ### 8. Evaluate

# %%
evaluate(
    model = model,
    data_loader = train_loader,  # evaluate on training data
    criterion = criterion,
    device = DEVICE,
)
# Out:
# Evaluation Results:
# Loss: 0.0563, Accuracy: 98.51%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      4735
#            1       0.98      1.00      0.99      5383
#            2       0.99      0.98      0.98      4762
#            3       0.98      0.98      0.98      4886
#            4       0.99      0.98      0.98      4681
#            5       0.99      0.98      0.98      4368
#            6       0.99      0.99      0.99      4752
#            7       0.98      0.99      0.99      4983
#            8       0.98      0.99      0.98      4674
#            9       0.97      0.98      0.98      4776
#
#     accuracy                           0.99     48000
#    macro avg       0.99      0.98      0.99     48000
# weighted avg       0.99      0.99      0.99     48000

# %%
evaluate(
    model = model,
    data_loader = val_loader,  # evaluate on validation data
    criterion = criterion,
    device = DEVICE,
)
# Out:
# Evaluation Results:
# Loss: 0.1000, Accuracy: 97.12%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1188
#            1       0.98      0.99      0.98      1359
#            2       0.98      0.96      0.97      1196
#            3       0.96      0.97      0.97      1245
#            4       0.98      0.97      0.97      1161
#            5       0.97      0.96      0.97      1053
#            6       0.98      0.98      0.98      1166
#            7       0.97      0.98      0.97      1282
#            8       0.97      0.97      0.97      1177
#            9       0.95      0.96      0.95      1173
#
#     accuracy                           0.97     12000
#    macro avg       0.97      0.97      0.97     12000
# weighted avg       0.97      0.97      0.97     12000

# %%
evaluate(
    model = model,
    data_loader = test_loader,  # evaluate on testing data
    criterion = criterion,
    device = DEVICE,
)
# Out:
# Evaluation Results:
# Loss: 0.0862, Accuracy: 97.31%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.98      0.99      0.98      1135
#            2       0.98      0.96      0.97      1032
#            3       0.96      0.98      0.97      1010
#            4       0.98      0.97      0.97       982
#            5       0.99      0.96      0.97       892
#            6       0.98      0.97      0.98       958
#            7       0.97      0.97      0.97      1028
#            8       0.96      0.97      0.96       974
#            9       0.97      0.96      0.96      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000

# %%
#with help of my partner and pytorch documentation to create more of an output

selection = random.randrange(len(train)-1)
image, label = train[selection]
image = image.view([28,28])

plt.imshow(image, cmap="gray")
image = torch.flatten(image)

result = model(image)
print(result)
value,prediction = torch.max(result,0)
print(f"Value: {value}; Prediction: {prediction}")
# Out:
# tensor([13.7450, -6.9973,  5.4902,  0.7912, -8.2311, -3.4595, -3.1087,  2.0995,
#         -0.7676,  0.7332], grad_fn=<ViewBackward0>)
# Value: 13.745035171508789; Prediction: 0
